# %% [markdown]
# ## Importing statements

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## reading the image and setting the kernel

# %%
img = cv2.imread("child.jpg")
kernel = np.ones((5,5),np.uint8)
plt.imshow(img)

# %% [markdown]
# ## erosion

# %%
erosion = cv2.erode(img,kernel)
plt.imshow(erosion)

# %% [markdown]
# ## Dilation

# %%
dilation = cv2.dilate(img,kernel)
plt.imshow(erosion)
